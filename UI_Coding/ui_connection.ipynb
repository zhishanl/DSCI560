# %%
# !pip install anvil-uplink

# %%
import numpy as np
import pandas as pd
import anvil.server
from datetime import datetime, timedelta
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#connect this notebook to our Anvil web app
anvil.server.connect("ZZPIEMAPQ4KEYY74UZFBB4TS-BGSQVLK3H45Q57QD")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment" as SERVER

# %%
pred_df = pd.read_csv("final_data.csv")
pred_df
# Out:
#         date timeframe  floor_level  prediction
# 0     3/6/20      8:00            0         158
# 1     3/6/20      9:00            0         199
# 2     3/6/20     10:00            0         247
# 3     3/6/20     11:00            0         247
# 4     3/6/20     12:00            0         232
# ..       ...       ...          ...         ...
# 215  3/10/20     14:00            3          38
# 216  3/10/20     15:00            3          18
# 217  3/10/20     16:00            3           8
# 218  3/10/20     17:00            3           4
# 219  3/10/20     18:00            3           2
#
# [220 rows x 4 columns]

# %%
# round time into nearest hour
def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +timedelta(hours=t.minute//30))

# %%
# now = datetime.now()
# print(now.hour+5)
# if (now.hour+5) > 18:
#     print(now.hour+5)
#     print("hello")
# else:
#     print(False)
# next_hour = now + timedelta(hours=24)
# next_hour = hour_rounder(next_hour)
# next_hour = next_hour.strftime('%H:%M')
# next_hour

# %%
# closest_date = pred_df['date'].min()

# date_1 = datetime.strptime(closest_date, "%m/%d/%y")
# adding = date_1 + timedelta(days=1)
# end_date = adding.strftime('%-m/%-d/%y')

# hour_1_day = now + timedelta(hours=24)
# hour_1_day = hour_rounder(hour_1_day)
# hour_1_day = hour_1_day.strftime('%H:%M')

# %%
@anvil.server.callable

def result_output(timeframe, floor_level):
    
    now = datetime.now()
    
    result_list = []
    
    closest_date = pd.to_datetime(pred_df['date']).min()
    closest_date = closest_date.strftime('%-m/%-d/%y')
    
    if now.hour < 8 or now.hour > 18:
        result_list.append('Less than 5 people')
        
    else:
        
        if timeframe == '1 Hour':
            if (now.hour+1) < 8 or (now.hour+1) > 18:
                result_list.append('Less than 5 people')
            
            else:
                # get the next hour time
                next_hour = now + timedelta(hours=1)
                next_hour = hour_rounder(next_hour)
                next_hour = next_hour.strftime('%H:%M')
        

                if floor_level == 'Ground Floor':
                    # qualifed condition in dataframe 
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==next_hour) & (pred_df['floor_level']==0)]
                    result_list.append(result['prediction'].item())


                if floor_level == 'First Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==next_hour) & (pred_df['floor_level']==1)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Second Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==next_hour) & (pred_df['floor_level']==2)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Third Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==next_hour) & (pred_df['floor_level']==3)]
                    result_list.append(result['prediction'].item())

        if timeframe == '3 Hour':
            
            if (now.hour+3) < 8 or (now.hour+3) > 18:
                result_list.append('Less than 5 people')
            
            else:
                # get the next 3 hour time
                hour3 = now + timedelta(hours=3)
                hour3 = hour_rounder(hour3)
                hour3 = hour3.strftime('%H:%M')

                if floor_level == 'Ground Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour3) & (pred_df['floor_level']==0)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'First Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour3) & (pred_df['floor_level']==1)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Second Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour3) & (pred_df['floor_level']==2)]
                    result_list.append(result['prediction'].item())


                if floor_level == 'Third Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour3) & (pred_df['floor_level']==3)]
                    result_list.append(result['prediction'].item())

        if timeframe == '5 Hour':
            if (now.hour+5) < 8 or (now.hour+5) > 18:
                result_list.append('Less than 5 people')
            
            else:
                # get the next 5 hour time
                hour5 = now + timedelta(hours=5)
                print(hour5)
                hour5 = hour_rounder(hour5)
                print(hour5)
                hour5 = hour5.strftime('%H:%M')
                print(hour5)

                if floor_level == 'Ground Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour5) & (pred_df['floor_level']==0)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'First Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour5) & (pred_df['floor_level']==1)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Second Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour5) & (pred_df['floor_level']==2)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Third Floor':
                    result = pred_df[(pred_df['date']==closest_date) & (pred_df['timeframe']==hour5) & (pred_df['floor_level']==3)]
                    result_list.append(result['prediction'].item())


        if timeframe == '1 Day After':
            if now.hour < 8 or now.hour > 18:
                result_list.append('Less than 5 people')
            
            else:
                date_1 = datetime.strptime(closest_date, "%m/%d/%y")
                adding = date_1 + timedelta(days=1)
                end_date = adding.strftime('%-m/%-d/%y')

                hour_1_day = now + timedelta(hours=24)
                hour_1_day = hour_rounder(hour_1_day)
                hour_1_day = hour_1_day.strftime('%H:%M')

                if floor_level == 'Ground Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_1_day) & (pred_df['floor_level']==0)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'First Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_1_day) & (pred_df['floor_level']==1)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Second Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_1_day) & (pred_df['floor_level']==2)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Third Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_1_day) & (pred_df['floor_level']==3)]
                    result_list.append(result['prediction'].item())

        if timeframe == '3 Days After':
            if now.hour < 8 or now.hour > 18:
                            result_list.append('Less than 5 people')
            
            else:
                date_1 = datetime.strptime(closest_date, "%m/%d/%y")
                adding = date_1 + timedelta(days=2)
                end_date = adding.strftime('%-m/%-d/%y')

                hour_3_day = now + timedelta(hours=72)
                hour_3_day = hour_rounder(hour_3_day)
                hour_3_day = hour_3_day.strftime('%H:%M')

                if floor_level == 'Ground Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_3_day) & (pred_df['floor_level']==0)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'First Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_3_day) & (pred_df['floor_level']==1)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Second Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_3_day) & (pred_df['floor_level']==2)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Third Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_3_day) & (pred_df['floor_level']==3)]
                    result_list.append(result['prediction'].item())

        if timeframe == '5 Days After':
            if now.hour < 8 or now.hour > 18:
                result_list.append('Less than 5 people')
            
            else:
                date_1 = datetime.strptime(closest_date, "%m/%d/%y")
                adding = date_1 + timedelta(days=4)
                end_date = adding.strftime('%-m/%-d/%y')

                hour_5_day = now + timedelta(hours=120)
                hour_5_day = hour_rounder(hour_5_day)
                hour_5_day = hour_5_day.strftime('%H:%M')

                if floor_level == 'Ground Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_5_day) & (pred_df['floor_level']==0)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'First Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_5_day) & (pred_df['floor_level']==1)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Second Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_5_day) & (pred_df['floor_level']==2)]
                    result_list.append(result['prediction'].item())

                if floor_level == 'Third Floor':
                    result = pred_df[(pred_df['date']==end_date) & (pred_df['timeframe']==hour_5_day) & (pred_df['floor_level']==3)]
                    result_list.append(result['prediction'].item())

    return result_list

# %%
# @anvil.server.callable
# def plotting():
#     plot = plt.plot(pred_df['timeframe'], pred_df['prediction'])
#     return plot


import base64
from io import BytesIO
from bokeh.plotting import figure, output_file, show
import anvil.media

# fig = plt.figure()
# #plot sth
# plt.plot(pred_df['timeframe'], pred_df['prediction'])

# tmpfile = BytesIO()
# fig.savefig(tmpfile, format='png')
# encoded = base64.b64encode(tmpfile.getvalue()).decode('utf-8')

# html = '<img src=\'data:image/png;base64,{}\'>'.format(encoded)

# with open('test.html','w') as f:
#     f.write(html)





@anvil.server.callable
def make_plot():
    # Point Bokeh at a file
    output_file("test.html")

    # Make a nice wiggle
#     x = np.arange(0.0, 5.0, 0.02)
#     y = np.exp(-x) * np.cos(2*np.pi*x)
    x = pred_df['timeframe']
    y = pred_df['prediction']

    # Plot it in the usual Bokeh way
    p = figure(width=600, height=300)
    p.line(x, y)

    # Save the plot  
    show(p)

    # Return this plot as HTML in a Media object
    return anvil.media.from_file('test.html', 'text/html')
